# %% [markdown]
# #### Merging data from Crunchbase and US Spending

# %%
pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzyNote: you may need to restart the kernel to use updated packages.
#
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
pip install Levenshtein
# Out:
# Collecting Levenshtein
#   Downloading Levenshtein-0.25.1-cp38-cp38-win_amd64.whl.metadata (3.4 kB)
# Collecting rapidfuzz<4.0.0,>=3.8.0 (from Levenshtein)
#   Downloading rapidfuzz-3.9.7-cp38-cp38-win_amd64.whl.metadata (12 kB)
# Downloading Levenshtein-0.25.1-cp38-cp38-win_amd64.whl (98 kB)
# Downloading rapidfuzz-3.9.7-cp38-cp38-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------------------- -- 1.6/1.7 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 6.4 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein
# Successfully installed Levenshtein-0.25.1 rapidfuzz-3.9.7
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from fuzzywuzzy import process

# %% [markdown]
# **Load the Crunchbase data**:

# %%
# load the cleaned Crunchbase data
cb_data = pd.read_csv('C:/Users/AM/OneDrive/Desktop/capstone/data/cleaned/cleaned_crunchbase_data.csv')

# display the first few rows and data info to verify
print(cb_data.head())
print(cb_data.info())
# Out:
#            company_name  year_founded  \
# 0                DIMAAG          2018
# 1               Netdata          2018
# 2  Outward Technologies          2017
# 3                TATINE          2015
# 4                   X3M          2022
#
#                                           Industries  \
# 0  Artificial Intelligence (AI), Autonomous Vehic...
# 1  Enterprise Software, Information Technology, I...
# 2                       Aerospace, Commercial, Solar
# 3   E-Commerce, Home Decor, Manufacturing, Wholesale
# 4  Advertising, Advertising Platforms, Informatio...
#
#                                          hq  zipcode  \
# 0        Fremont, California, United States    94538
# 1  San Francisco, California, United States    94104
# 2       Broomfield, Colorado, United States    80020
# 3          Chicago, Illinois, United States    60639
# 4       Wilmington, Delaware, United States    19801
#
#                                          description operating_status  \
# 0  Building cutting-edge products and software se...           Active
# 1  Monitor your servers, containers, and applicat...           Active
# 2  Outward Technologies develops critical technol...           Active
# 3      TATINE manufactures and sells candles online.           Active
# 4  X3M improves ad monetization on mobile, giving...           Active
#
#    cb_rank       funding_status funding_date  ... num_funding_rounds  \
# 0   205664                    0   2020-01-27  ...                  1
# 1    29903  Early Stage Venture   2020-09-22  ...                  5
# 2    99546                    0   2020-09-11  ...                  2
# 3   766720                    0            0  ...                  0
# 4  1900792                    0            0  ...                  0
#
#   total_funding                                      top_investors  \
# 0             0      Plug and Play, Global Catalyst Partners Japan
# 1      34700000  Bessemer Venture Partners, Uncorrelated Ventur...
# 2       1175495                        National Science Foundation
# 3             0                                                  0
# 4             0                                                  0
#
#   num_investors  operating_status_binary  num_employees_cat  \
# 0             2                        1            101-250
# 1             5                        1             51-100
# 2             1                        1              11-50
# 3             0                        1               1-10
# 4             0                        1             51-100
#
#              clean_name           city       state        country
# 0                DIMAAG        Fremont  California  United States
# 1               NETDATA  San Francisco  California  United States
# 2  OUTWARD TECHNOLOGIES     Broomfield    Colorado  United States
# 3                TATINE        Chicago    Illinois  United States
# 4                   X3M     Wilmington    Delaware  United States
#
# [5 rows x 24 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 904 entries, 0 to 903
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   company_name             904 non-null    object
#  1   year_founded             904 non-null    int64
#  2   Industries               904 non-null    object
#  3   hq                       904 non-null    object
#  4   zipcode                  904 non-null    int64
#  5   description              904 non-null    object
#  6   operating_status         904 non-null    object
#  7   cb_rank                  904 non-null    int64
#  8   funding_status           904 non-null    object
#  9   funding_date             904 non-null    object
#  10  funding_type             904 non-null    object
#  11  ipo_status               904 non-null    object
#  12  estimated_revenue        904 non-null    object
#  13  num_employees            904 non-null    object
#  14  num_funding_rounds       904 non-null    int64
#  15  total_funding            904 non-null    int64
#  16  top_investors            904 non-null    object
#  17  num_investors            904 non-null    int64
#  18  operating_status_binary  904 non-null    int64
#  19  num_employees_cat        878 non-null    object
#  20  clean_name               904 non-null    object
#  21  city                     904 non-null    object
#  22  state                    904 non-null    object
#  23  country                  904 non-null    object
# dtypes: int64(7), object(17)
# memory usage: 169.6+ KB
# None

# %% [markdown]
# **Load the US Spending data**:

# %%
# load the cleaned USA Spending data
usa_spending = pd.read_csv('C:/Users/AM/OneDrive/Desktop/capstone/data/cleaned/cleaned_usa_spending_data.csv')

# display the first few rows and data info to verify
print(usa_spending.head())
print(usa_spending.info())
# Out:
#                    contract_award_unique_key  award_id_piid  \
# 0  CONT_AWD_80NSSC20C0664_8000_-NONE-_-NONE-  80NSSC20C0664
# 1  CONT_AWD_80NSSC20C0151_8000_-NONE-_-NONE-  80NSSC20C0151
# 2  CONT_AWD_80NSSC19C0347_8000_-NONE-_-NONE-  80NSSC19C0347
# 3  CONT_AWD_80NSSC18C0024_8000_-NONE-_-NONE-  80NSSC18C0024
# 4  CONT_AWD_80NSSC18C0093_8000_-NONE-_-NONE-  80NSSC18C0093
#
#    total_obligated_amount  current_total_value_of_award  \
# 0                122531.0                      122531.0
# 1                741929.0                      741929.0
# 2                121417.0                      121417.0
# 3               1348131.0                      948134.0
# 4                749999.0                      749999.0
#
#    potential_total_value_of_award award_base_action_date  \
# 0                        122531.0             2020-08-28
# 1                        741929.0             2020-06-27
# 2                        121417.0             2019-08-19
# 3                        948136.0             2018-05-25
# 4                        749999.0             2018-04-24
#
#    award_base_action_year current_end_date  \
# 0                    2020       2021-03-01
# 1                    2020       2022-06-23
# 2                    2019       2020-02-18
# 3                    2018       2022-02-24
# 4                    2018       2020-10-23
#
#                             awarding_agency_name  \
# 0  National Aeronautics and Space Administration
# 1  National Aeronautics and Space Administration
# 2  National Aeronautics and Space Administration
# 3  National Aeronautics and Space Administration
# 4  National Aeronautics and Space Administration
#
#                         awarding_sub_agency_name  ...  \
# 0  National Aeronautics and Space Administration  ...
# 1  National Aeronautics and Space Administration  ...
# 2  National Aeronautics and Space Administration  ...
# 3  National Aeronautics and Space Administration  ...
# 4  National Aeronautics and Space Administration  ...
#
#   primary_place_of_performance_state_code           award_type  \
# 0                                      MA  DEFINITIVE CONTRACT
# 1                                      MA  DEFINITIVE CONTRACT
# 2                                      MA  DEFINITIVE CONTRACT
# 3                                      MA  DEFINITIVE CONTRACT
# 4                                      MA  DEFINITIVE CONTRACT
#
#   type_of_contract_pricing                product_or_service_code_description  \
# 0         FIRM FIXED PRICE  R&D- SPACE: AERONAUTICS/SPACE TECHNOLOGY (BASI...
# 1         FIRM FIXED PRICE  SPACE R&D SERVICES; SPACE FLIGHT, RESEARCH AND...
# 2         FIRM FIXED PRICE  R&D- SPACE: AERONAUTICS/SPACE TECHNOLOGY (BASI...
# 3         FIRM FIXED PRICE  SPACE R&D SERVICES; SPACE FLIGHT, RESEARCH AND...
# 4         FIRM FIXED PRICE  R&D- SPACE: AERONAUTICS/SPACE TECHNOLOGY (BASI...
#
#   naics_code                                  naics_description  \
# 0     541715  RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...
# 1     541715  RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...
# 2     541715  RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...
# 3     541715  RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...
# 4     541715  RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...
#
#    number_of_offers_received       organizational_type  \
# 0                        500               PARTNERSHIP
# 1                          1  CORPORATE NOT TAX EXEMPT
# 2                        500  CORPORATE NOT TAX EXEMPT
# 3                        500  CORPORATE NOT TAX EXEMPT
# 4                        500  CORPORATE NOT TAX EXEMPT
#
#             clean_recipient_name    clean_recipient_parent_name
# 0                  SOLVUS GLOBAL                  SOLVUS GLOBAL
# 1  MAGNOLIA OPTICAL TECHNOLOGIES  MAGNOLIA OPTICAL TECHNOLOGIES
# 2  MAGNOLIA OPTICAL TECHNOLOGIES  MAGNOLIA OPTICAL TECHNOLOGIES
# 3  MAGNOLIA OPTICAL TECHNOLOGIES  MAGNOLIA OPTICAL TECHNOLOGIES
# 4  MAGNOLIA OPTICAL TECHNOLOGIES  MAGNOLIA OPTICAL TECHNOLOGIES
#
# [5 rows x 28 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5289 entries, 0 to 5288
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   contract_award_unique_key                5289 non-null   object
#  1   award_id_piid                            5289 non-null   object
#  2   total_obligated_amount                   5289 non-null   float64
#  3   current_total_value_of_award             5289 non-null   float64
#  4   potential_total_value_of_award           5289 non-null   float64
#  5   award_base_action_date                   5289 non-null   object
#  6   award_base_action_year                   5289 non-null   int64
#  7   current_end_date                         5024 non-null   object
#  8   awarding_agency_name                     5289 non-null   object
#  9   awarding_sub_agency_name                 5289 non-null   object
#  10  funding_agency_name                      5289 non-null   object
#  11  funding_sub_agency_name                  5289 non-null   object
#  12  recipient_name                           5289 non-null   object
#  13  recipient_parent_name                    5289 non-null   object
#  14  recipient_city_name                      5289 non-null   object
#  15  recipient_state_code                     5289 non-null   object
#  16  recipient_zipcode                        5289 non-null   int64
#  17  primary_place_of_performance_city_name   5289 non-null   object
#  18  primary_place_of_performance_state_code  5289 non-null   object
#  19  award_type                               5289 non-null   object
#  20  type_of_contract_pricing                 5289 non-null   object
#  21  product_or_service_code_description      5289 non-null   object
#  22  naics_code                               5289 non-null   int64
#  23  naics_description                        5289 non-null   object
#  24  number_of_offers_received                5289 non-null   int64
#  25  organizational_type                      5289 non-null   object
#  26  clean_recipient_name                     5289 non-null   object
#  27  clean_recipient_parent_name              5289 non-null   object
# dtypes: float64(3), int64(4), object(21)
# memory usage: 1.1+ MB
# None

# %% [markdown]
# **Merging**

# %%
def optimized_levenshtein_merge(df1, df2, key1, key2, threshold=90):
    # create sets of unique company names
    names1 = set(df1[key1].unique())
    names2 = set(df2[key2].unique())
    
    # find matches for names in df1
    matches = {}
    for name in names1:
        match = process.extractOne(name, names2, score_cutoff=threshold)
        if match:
            matches[name] = match
    
    # create a mapping dictionary
    mapping = {name: match[0] for name, match in matches.items()}
    
    # apply the mapping to df1
    df1['match_company'] = df1[key1].map(mapping)
    df1['match_score'] = df1[key1].map(lambda x: matches.get(x, (None, None))[1])
    
    return df1

# %%
# perform the merge 
merged_data = optimized_levenshtein_merge(cb_data, usa_spending, 'clean_name', 'clean_recipient_name')

# %%
# display results
print(merged_data[['clean_name', 'match_company', 'match_score']].head(20))
print(f"Total matches found: {merged_data['match_company'].notna().sum()}")
# Out:
#                    clean_name match_company  match_score
# 0                      DIMAAG           NaN          NaN
# 1                     NETDATA           NaN          NaN
# 2        OUTWARD TECHNOLOGIES           NaN          NaN
# 3                      TATINE           NaN          NaN
# 4                         X3M           NaN          NaN
# 5                       DUEXT           NaN          NaN
# 6                       PEMRS           NaN          NaN
# 7       SOLSTAR SPACE COMPANY           NaN          NaN
# 8                      BLAKFX           NaN          NaN
# 9              REACTIVE SPACE           NaN          NaN
# 10                   SPACE K9           NaN          NaN
# 11          BESTMARK NATIONAL           NaN          NaN
# 12          APHELION ORBITALS           NaN          NaN
# 13            HEALTHHIVE, PBC           NaN          NaN
# 14                     EDEKEE           NaN          NaN
# 15           BEARLY SOLUTIONS           NaN          NaN
# 16       HUDSON SPACE SYSTEMS           NaN          NaN
# 17                 GO DIGITAL           NaN          NaN
# 18                 CRYPTO PRO           NaN          NaN
# 19  MARKET PROS INTERNATIONAL           NaN          NaN
# Total matches found: 67

# %%
successful_matches = merged_data[merged_data['match_company'].notna()]
print(successful_matches[['clean_name', 'match_company', 'match_score']].head(20))
# Out:
#                   clean_name                match_company  match_score
# 20                   DIGITAL  TELEDYNE DIGITAL IMAGING US         90.0
# 21   BENCHMARK SPACE SYSTEMS      BENCHMARK SPACE SYSTEMS        100.0
# 59                    RADIAN   RADIANT ANALYTIC SOLUTIONS         90.0
# 62             SPACE FOUNDRY                SPACE FOUNDRY        100.0
# 74             LUNAR OUTPOST                LUNAR OUTPOST        100.0
# 75      APOGEE SEMICONDUCTOR         APOGEE SEMICONDUCTOR        100.0
# 80                      NOVI                         NOVI        100.0
# 83                  INVINOVO                          NVI         90.0
# 111              STOKE SPACE     STOKE SPACE TECHNOLOGIES         90.0
# 115                 NFLUX AI                        NFLUX         90.0
# 118                  G-SPACE                       GSPACE         92.0
# 132               WHYTESPACE                       ESPACE         90.0
# 133                  REDWIRE      REDWIRE SPACE SOLUTIONS         90.0
# 136                 BLUEHALO                BLUEHALO LABS         90.0
# 144              MAGMA SPACE                  MAGMA SPACE        100.0
# 147   MARTIAN SKY INDUSTRIES       MARTIAN SKY INDUSTRIES        100.0
# 162            QUANTUM SPACE                QUANTUM SPACE        100.0
# 167                  OUTPOST         OUTPOST TECHNOLOGIES         90.0
# 179              METTA SPACE                    ETA SPACE         90.0
# 182                     ELIS      MARICELIS ROMAN MIRANDA         90.0

# %%
# print column names for Crunchbase data
print("Crunchbase Data Columns:")
print(cb_data.columns.tolist())

# print column names for USA Spending data
print("\nUSA Spending Data Columns:")
print(usa_spending.columns.tolist())
# Out:
# Crunchbase Data Columns:
# ['company_name', 'year_founded', 'Industries', 'hq', 'zipcode', 'description', 'operating_status', 'cb_rank', 'funding_status', 'funding_date', 'funding_type', 'ipo_status', 'estimated_revenue', 'num_employees', 'num_funding_rounds', 'total_funding', 'top_investors', 'num_investors', 'operating_status_binary', 'num_employees_cat', 'clean_name', 'city', 'state', 'country', 'match_company', 'match_score']
#
# USA Spending Data Columns:
# ['contract_award_unique_key', 'award_id_piid', 'total_obligated_amount', 'current_total_value_of_award', 'potential_total_value_of_award', 'award_base_action_date', 'award_base_action_year', 'current_end_date', 'awarding_agency_name', 'awarding_sub_agency_name', 'funding_agency_name', 'funding_sub_agency_name', 'recipient_name', 'recipient_parent_name', 'recipient_city_name', 'recipient_state_code', 'recipient_zipcode', 'primary_place_of_performance_city_name', 'primary_place_of_performance_state_code', 'award_type', 'type_of_contract_pricing', 'product_or_service_code_description', 'naics_code', 'naics_description', 'number_of_offers_received', 'organizational_type', 'clean_recipient_name', 'clean_recipient_parent_name']

# %%
# renaming certain columns based on findings
merged_data = merged_data.rename(columns={
    'hq': 'cb_hq',  # Headquarters
    'Industries': 'industries' #lowercase
})

# %%
def review_matches(successful_matches):
    verified_matches = []
    for _, row in successful_matches.iterrows():
        print(f"\nCrunchbase: {row['clean_name']} ({row['city']})")
        print(f"USA Spending: {row['match_company']}")
        print(f"Match Score: {row['match_score']}")
        keep = input("Keep this match? (y/n): ").lower().strip()
        if keep == 'y':
            verified_matches.append(row)
    return pd.DataFrame(verified_matches)

verified_matches = review_matches(successful_matches)
# Out:
# Crunchbase: DIGITAL (Greenwich)
# USA Spending: TELEDYNE DIGITAL IMAGING US
# Match Score: 90.0
#
# Crunchbase: BENCHMARK SPACE SYSTEMS (South Burlington)
# USA Spending: BENCHMARK SPACE SYSTEMS
# Match Score: 100.0
#
# Crunchbase: RADIAN (Bellevue)
# USA Spending: RADIANT ANALYTIC SOLUTIONS
# Match Score: 90.0
#
# Crunchbase: SPACE FOUNDRY (San Jose)
# USA Spending: SPACE FOUNDRY
# Match Score: 100.0
#
# Crunchbase: LUNAR OUTPOST (Golden)
# USA Spending: LUNAR OUTPOST
# Match Score: 100.0
#
# Crunchbase: APOGEE SEMICONDUCTOR (Plano)
# USA Spending: APOGEE SEMICONDUCTOR
# Match Score: 100.0
#
# Crunchbase: NOVI (Arlington)
# USA Spending: NOVI
# Match Score: 100.0
#
# Crunchbase: INVINOVO (San Diego)
# USA Spending: NVI
# Match Score: 90.0
#
# Crunchbase: STOKE SPACE (Kent)
# USA Spending: STOKE SPACE TECHNOLOGIES
# Match Score: 90.0
#
# Crunchbase: NFLUX AI (Los Angeles)
# USA Spending: NFLUX
# Match Score: 90.0
#
# Crunchbase: G-SPACE (Sunnyvale)
# USA Spending: GSPACE
# Match Score: 92.0
#
# Crunchbase: WHYTESPACE (Chicago)
# USA Spending: ESPACE
# Match Score: 90.0
#
# Crunchbase: REDWIRE (Jacksonville)
# USA Spending: REDWIRE SPACE SOLUTIONS
# Match Score: 90.0
#
# Crunchbase: BLUEHALO (Arlington)
# USA Spending: BLUEHALO LABS
# Match Score: 90.0
#
# Crunchbase: MAGMA SPACE (Washington)
# USA Spending: MAGMA SPACE
# Match Score: 100.0
#
# Crunchbase: MARTIAN SKY INDUSTRIES (Cleveland)
# USA Spending: MARTIAN SKY INDUSTRIES
# Match Score: 100.0
#
# Crunchbase: QUANTUM SPACE (Rockville)
# USA Spending: QUANTUM SPACE
# Match Score: 100.0
#
# Crunchbase: OUTPOST (Los Angeles)
# USA Spending: OUTPOST TECHNOLOGIES
# Match Score: 90.0
#
# Crunchbase: METTA SPACE (Los Angeles)
# USA Spending: ETA SPACE
# Match Score: 90.0
#
# Crunchbase: ELIS (New York)
# USA Spending: MARICELIS ROMAN MIRANDA
# Match Score: 90.0
#
# Crunchbase: HALO (Houston)
# USA Spending: BLUEHALO LABS
# Match Score: 90.0
#
# Crunchbase: EMERGE (Los Angeles)
# USA Spending: EMERGENT SPACE TECHNOLOGIES
# Match Score: 90.0
#
# Crunchbase: NABLA ZERO LABS (Pasadena)
# USA Spending: NABLA ZERO LABS
# Match Score: 100.0
#
# Crunchbase: STRATOS PERCEPTION (Houston)
# USA Spending: STRATOS PERCEPTION
# Match Score: 100.0
#
# Crunchbase: REBEL SPACE TECHNOLOGIES (Long Beach)
# USA Spending: REBEL SPACE TECHNOLOGIES
# Match Score: 100.0
#
# Crunchbase: SEEK (New York)
# USA Spending: SENSEEKER
# Match Score: 90.0
#
# Crunchbase: ROCKET PROPULSION SYSTEMS (Kent)
# USA Spending: ROCKET PROPULSION SYSTEMS
# Match Score: 100.0
#
# Crunchbase: SPECTER (Auburn)
# USA Spending: SPECTER AEROSPACE
# Match Score: 90.0
#
# Crunchbase: HELIOSPACE (Berkeley)
# USA Spending: HELIOSPACE
# Match Score: 100.0
#
# Crunchbase: AALYRIA (Livermore)
# USA Spending: AALYRIA TECHNOLOGIES
# Match Score: 90.0
#
# Crunchbase: GOGOGUEST, (San Francisco)
# USA Spending: UES
# Match Score: 90.0
#
# Crunchbase: MENTIUM TECHNOLOGIES (Santa Barbara)
# USA Spending: MENTIUM TECHNOLOGIES
# Match Score: 100.0
#
# Crunchbase: GLOBAL AIR LOGISTICS AND TRAINING (Del Mar)
# USA Spending: GLOBAL AIR LOGISTICS AND TRAINING
# Match Score: 100.0
#
# Crunchbase: VESTIGO AEROSPACE (La Canada Flintridge)
# USA Spending: VESTIGO AEROSPACE
# Match Score: 100.0
#
# Crunchbase: RELATIVITY SPACE (Long Beach)
# USA Spending: RELATIVITY SPACE
# Match Score: 100.0
#
# Crunchbase: EMERGE (Marina Del Rey)
# USA Spending: EMERGENT SPACE TECHNOLOGIES
# Match Score: 90.0
#
# Crunchbase: VECTOR LAUNCH (Tucson)
# USA Spending: VECTOR LAUNCH
# Match Score: 100.0
#
# Crunchbase: CACTUS MATERIALS (Tempe)
# USA Spending: CACTUS MATERIALS
# Match Score: 100.0
#
# Crunchbase: TACTIC (Lehi)
# USA Spending: JOINT TACTICS AND TECHNOLOGIES
# Match Score: 90.0
#
# Crunchbase: PICKNIK ROBOTICS (Boulder)
# USA Spending: PICKNIK
# Match Score: 90.0
#
# Crunchbase: ORBITAL MICRO SYSTEMS (Boulder)
# USA Spending: ORBITAL MICRO SYSTEMS
# Match Score: 100.0
#
# Crunchbase: SPACE LAB TECHNOLOGIES (Boulder)
# USA Spending: SPACE LAB TECHNOLOGIES
# Match Score: 100.0
#
# Crunchbase: URBAN SKY (Denver)
# USA Spending: URBAN SKY THEORY
# Match Score: 90.0
#
# Crunchbase: XAIROS (Highlands Ranch)
# USA Spending: XAIROS SYSTEMS
# Match Score: 90.0
#
# Crunchbase: TENDEG (Louisville)
# USA Spending: TENDEG
# Match Score: 100.0
#
# Crunchbase: SIERRA SPACE (Louisville)
# USA Spending: SIERRA SPACE
# Match Score: 100.0
#
# Crunchbase: ORBIT FAB (Lafayette)
# USA Spending: ORBIT FAB
# Match Score: 100.0
#
# Crunchbase: CESIUMASTRO (Austin)
# USA Spending: CESIUMASTRO
# Match Score: 100.0
#
# Crunchbase: AXIOM SPACE (Houston)
# USA Spending: AXIOM SPACE
# Match Score: 100.0
#
# Crunchbase: COGNITIVE SPACE (Houston)
# USA Spending: COGNITIVE SPACE
# Match Score: 100.0
#
# Crunchbase: IMPOSSIBLE SENSING (St Louis)
# USA Spending: IMPOSSIBLE SENSING
# Match Score: 100.0
#
# Crunchbase: ORBION SPACE TECHNOLOGY (Houghton)
# USA Spending: ORBION SPACE TECHNOLOGY
# Match Score: 100.0
#
# Crunchbase: ATLAS SPACE OPERATIONS (Traverse City)
# USA Spending: ATLAS SPACE OPERATIONS
# Match Score: 100.0
#
# Crunchbase: ENGENIX (Huntsville)
# USA Spending: ENGENIX
# Match Score: 100.0
#
# Crunchbase: INTERSTELLAR TECHNOLOGIES (Huntsville)
# USA Spending: INTERSTEL TECHNOLOGIES
# Match Score: 94.0
#
# Crunchbase: SPACE-TECH (Fort Myers)
# USA Spending: EMERGENT SPACE TECHNOLOGIES
# Match Score: 90.0
#
# Crunchbase: ETA SPACE (Rockledge)
# USA Spending: ETA SPACE
# Match Score: 100.0
#
# Crunchbase: MODULARITY SPACE (Daytona Beach)
# USA Spending: MODULARITY
# Match Score: 90.0
#
# Crunchbase: AXE (Greensboro)
# USA Spending: MAXENTRIC TECHNOLOGIES
# Match Score: 90.0
#
# Crunchbase: PSIONIC (Hampton)
# USA Spending: PSIONIC
# Match Score: 100.0
#
# Crunchbase: RAYTHEON INTELLIGENCE & SPACE (Arlington)
# USA Spending: RAYTHEON
# Match Score: 90.0
#
# Crunchbase: SPACELINK (Mclean)
# USA Spending: SPACELINK
# Match Score: 100.0
#
# Crunchbase: TRUSTED SPACE (Leesburg)
# USA Spending: TRUSTED SPACE
# Match Score: 100.0
#
# Crunchbase: PERATON (Herndon)
# USA Spending: PERATON
# Match Score: 100.0
#
# Crunchbase: APPLIED PHYSICS (New York)
# USA Spending: THE JOHNS HOPKINS UNIVERSITY APPLIED PHYSICS LABORATORY
# Match Score: 90.0
#
# Crunchbase: ORI (Boston)
# USA Spending: SPORIAN MICROSYSTEMS
# Match Score: 90.0
#
# Crunchbase: MAVENVIEW (Columbus)
# USA Spending: NVI
# Match Score: 90.0

# %%
# update the merged dataset with verified matches
merged_data.loc[verified_matches.index, 'match_company'] = verified_matches['match_company']
merged_data.loc[verified_matches.index, 'match_score'] = verified_matches['match_score']

# remove unverified matches
merged_data.loc[~merged_data.index.isin(verified_matches.index), ['match_company', 'match_score']] = np.nan

print(f"Total verified matches: {len(verified_matches)}")
# Out:
# Total verified matches: 50

# %%
# Filter to keep only rows with valid matches
matched_data = merged_data[merged_data['match_company'].notna()]

# Save the filtered DataFrame to a new CSV file
matched_data.to_csv('matched_data.csv', index=False)

print("Matched data saved as 'matched_data.csv'.")
# Out:
# Matched data saved as 'matched_data.csv'.
